# %% [markdown]
# # Aero time Benchmark (AVL, ASB)

# %%
from amad.disciplines.aerodynamics.tools.benchmark_aero import benchmark_aero_flightpoint_avl
from amad.disciplines.aerodynamics.tools.benchmark_aero import benchmark_aero_flightpoint_asb

# %%
time_avl = benchmark_aero_flightpoint_avl()
print('AVL ok:', time_avl)
time_asb = benchmark_aero_flightpoint_asb()

print(f'time AVL:{time_avl:.2f} time ASB:{time_asb:.2f}')
print(f'AVL takes {100 * time_avl / time_asb:.0f}% of the time')
# Out:
# AVL ok: 23.59816067898646
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/.conda/envs/amad/lib/python3.10/site-packages/aerosandbox/aerodynamics/aero_2D/xfoil.py:236, in XFoil._run_xfoil(self, run_command)
#     235 try:
# --> 236     subprocess.run(
#     237         f'{self.xfoil_command} {airfoil_file}',
#     238         input="\n".join(keystrokes),
#     239         cwd=directory,
#     240         stdout=None if self.verbose else subprocess.DEVNULL,
#     241         stderr=None if self.verbose else subprocess.DEVNULL,
#     242         text=True,
#     243         shell=True,
#     244         timeout=self.timeout,
#     245         check=True
#     246     )
#     247 except subprocess.TimeoutExpired:
#
# File ~/.conda/envs/amad/lib/python3.10/subprocess.py:524, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
# ...
